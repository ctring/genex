# %%
import matplotlib.pyplot as plt
import numpy as np
import dtw

# %%
 def plot_dtw(a, b, alabel, blabel, path, distance, offset=1):
    na = len(a)
    nb = len(b)
    
    xa = range(0, na)
    xb = np.arange(0, nb) + offset
  
    pairs = []
    path_x = []
    path_y = []
    for t in path:
        pairs.append([xa[t[0]], xb[t[1]]])
        pairs.append([a[t[0]], b[t[1]]])
        path_x.append(t[0])
        path_y.append(t[1])

    plt.plot(color='k', linestyle='--', linewidth=1, *pairs)
    plt.plot(xa, a, color='b', linestyle='-.', marker='o', linewidth=2, label=alabel)
    plt.plot(xb, b, color='r', linewidth=2, marker='x', label=blabel)
    plt.title('DTW distance = %.2f' % distance, fontsize=18)
    plt.legend(fontsize=13)

# %%
plt.figure(num=None, figsize=(10, 3), dpi=80, facecolor='w', edgecolor='k')

a = [0.31665,0.2432,0.37047,1.0637,1.6782,1.7596,1.6977,1.6122,1.1682,0.49996,-0.022363,-0.23532,-0.11827,-0.071027,-0.32299,-0.43356,-0.31866,-0.29565]
b = [0.31, 1.06, 1.60, 1.63, 1.60, 1.1, 0.3, -0.28]
d, path = dtw.dtw(a, b)
print 'distance:', d
plt.subplot(1, 2, 1)
plot_dtw(a, b, 'Query sample', '1st best match', path, d, 1.5)
plt.arrow(13.0, 0.6, 0, -0.3, head_width=0.4, head_length=0.1, fc='k')

a = [0.31665,0.2432,0.37047,1.0637,1.6782,1.7596,1.6977,1.6122,1.1682,0.49996,-0.022363,-0.23532,-0.11827,-0.071027,-0.32299,-0.43356,-0.31866,-0.29565]
b = [0.37, 0.4, 1.3, 1.56, 1.50, 1.33, 1.1, 0.3, -0.2, -0.25, -0.3, -0.15, -0.13, -0.2, -0.25]
d, path = dtw.dtw(a, b)
print 'distance:', d
plt.subplot(1, 2, 2)
plot_dtw(a, b, 'Query sample', '2nd best match', path, d)
plt.arrow(13.0, 0.6, 0, -0.3, head_width=0.4, head_length=0.1, fc='k')

plt.tight_layout()
plt.savefig('intro_reason_1.eps', dpi=200)

plt.show()
# Out:
# distance: 0.495805718602
# distance: 0.572597269464

# %%
plt.figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.11,0.56,0.40,0.50,0.27377,-0.4,-0.94234,-0.68503,-0.94912]
d, path = dtw.dtw(a, b)
print 'distance:', d
plt.subplot(2, 2, 1)
plot_dtw(a, b, 'Query sample', '1st best match', path, d, 0)

a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.20,0.56,0.40,0.55,0.27377,-0.5,-0.94234,-0.7,-1.0]
d, path = dtw.dtw(a, b)
print 'distance:', d
plt.subplot(2, 2, 2)
plot_dtw(a, b, 'Query sample', '2nd best match', path, d, 0)

a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.20,0.56,0.40,0.55,0.27377,-0.5,-0.94234,-0.7,-1.0]
d, path = dtw.dtw(a, b)
print 'distance:', d
plt.subplot(2, 2, 3)
plot_dtw(a, b, 'Query sample', '3rd best match', path, d, 0)

a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
b = [0.1,0.7, 0.7,2.41,3.0, 1.7,-0.2,-0.88,-0.10, -0.10, 0.60,0.44,0.48,0.27,-0.23,-0.94,-0.68,-0.94]
d, path = dtw.dtw(a, b)
print 'distance:', d
plt.subplot(2, 2, 4)
plot_dtw(a, b, 'Query sample', '4th best match', path, d, 0)

plt.tight_layout()
plt.savefig('intro_reason_2.eps', dpi=200)

plt.show()
# Out:
# distance: 0.378359317581
# distance: 0.449971386313
# distance: 0.449971386313
# distance: 0.670684504219

# %%
plt.figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')

a = [0.31665,0.2432,0.37047,1.0637,1.6782,1.7596,1.6977,1.6122,1.1682,0.49996,-0.022363,-0.23532,-0.11827,-0.071027,-0.32299,-0.43356,-0.31866,-0.29565]

plt.plot(a, color='b', linestyle='-.', marker='o', linewidth=2)
plt.tight_layout()
plt.savefig('query_1.png', dpi=200)

plt.show()

# %%
plt.figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')

b = [0.31, 1.06, 1.60, 1.63, 1.60, 1.1, 0.3, -0.28]

plt.plot(b, color='r', linewidth=2, marker='x')
plt.tight_layout()
plt.xlim(-1.0, 18)
plt.ylim(-0.5, 1.8)
plt.savefig('data_1_1.png', dpi=200)

plt.show()

# %%
plt.figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')

b = [0.37, 0.4, 1.3, 1.56, 1.50, 1.33, 1.1, 0.3, -0.2, -0.25, -0.3, -0.15, -0.13, -0.2, -0.25]

plt.plot(b, color='r', linewidth=2, marker='x')
plt.tight_layout()
plt.xlim(-1.0, 18)
plt.ylim(-0.5, 1.8)
plt.savefig('data_1_2.png', dpi=200)

plt.show()

# %%
plt.figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')

b = [0.37, 0.4, 0.9, 1.29, 1.30, 1.29, 1.1, 0.3, -0.2, -0.25, -0.3, -0.15, -0.13, -0.2, -0.25]

plt.plot(b, color='r', linewidth=2, marker='x')
plt.tight_layout()
plt.xlim(-1.0, 18)
plt.ylim(-0.5, 1.8)
plt.savefig('data_1_3.png', dpi=200)

plt.show()

# %%
plt.figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')

b = [0.37, 0.4, 0.9, 1.29, 1.30, 1.29, 1.1, 0.3, 0.0, -0.25, -0.22, -0.19, -0.10, -0.0, 0.25]

plt.plot(b, color='r', linewidth=2, marker='x')
plt.tight_layout()
plt.xlim(-1.0, 18)
plt.ylim(-0.5, 1.8)
plt.savefig('data_1_4.png', dpi=200)

plt.show()

# %%
plt.figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')

a = [0.31665,0.2432,0.37047,1.0637,1.6782,1.7596,1.6977,1.6122,1.1682,0.49996,-0.022363,-0.23532,-0.11827,-0.071027,-0.32299,-0.43356,-0.31866,-0.29565]
# b = [0.31, 1.06, 1.60, 1.63, 1.60, 1.1, 0.3, -0.28]
# b = [0.37, 0.4, 1.3, 1.56, 1.50, 1.33, 1.1, 0.3, -0.2, -0.25, -0.3, -0.15, -0.13, -0.2, -0.25]
# b = [0.37, 0.4, 0.9, 1.29, 1.30, 1.29, 1.1, 0.3, -0.2, -0.25, -0.3, -0.15, -0.13, -0.2, -0.25]
b = [0.37, 0.4, 0.9, 1.29, 1.30, 1.29, 1.1, 0.3, 0.0, -0.25, -0.22, -0.19, -0.10, -0.0, 0.25]

d, path = dtw.dtw(a, b)
print 'distance:', d

plot_dtw(a, b, 'Query sample', '4th best match', path, d, 1.5)
# plt.arrow(13.0, 0.6, 0, -0.3, head_width=0.4, head_length=0.1, fc='k')
plt.tight_layout()
plt.savefig('bestmatch_1_4.png', dpi=200)
plt.show()
# Out:
# distance: 1.11561036012

# %%
plt.figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')

a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]

# b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.11,0.56,0.40,0.50,0.27377,-0.4,-0.94234,-0.68503,-0.94912]
# b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.20,0.56,0.40,0.55,0.27377,-0.5,-0.94234,-0.7,-1.0]
# b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.20,0.56,0.40,0.55,0.27377,-0.5,-0.94234,-0.7,-1.0]
# b = [0.1,0.7, 0.7,2.41,3.0, 1.7,-0.2,-0.88,-0.10, -0.10, 0.60,0.44,0.48,0.27,-0.23,-0.94,-0.68,-0.94]

plt.plot(a, color='b', linewidth=2, marker='o')
plt.xlim(-1.0, 18)
plt.ylim(-1.7, 4)
plt.tight_layout()
plt.savefig('query_2.png', dpi=200)

plt.show()

# %%
plt.figure(num=None, figsize=(5,3), dpi=80, facecolor='w', edgecolor='k')

# a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
# b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.11,0.56,0.40,0.50,0.27377,-0.4,-0.94234,-0.68503,-0.94912]
# d, path = dtw.dtw(a, b)
# print 'distance:', d

# plot_dtw(a, b, 'Query sample', '1st best match', path, d, 0)

# a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
# b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.20,0.56,0.40,0.55,0.27377,-0.5,-0.94234,-0.7,-1.0]
# d, path = dtw.dtw(a, b)
# print 'distance:', d

# plot_dtw(a, b, 'Query sample', '2nd best match', path, d, 0)

# a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
# b = [0.29477,0.86093,2.3,3.2,2.0206,-0.01906,-0.80,-0.20,0.56,0.40,0.55,0.27377,-0.5,-0.94234,-0.7,-1.0]
# d, path = dtw.dtw(a, b)
# print 'distance:', d

# plot_dtw(a, b, 'Query sample', '3rd best match', path, d, 0)

a = [0.29477,0.86093,2.4192,3.4521,2.0206,-0.01906,-0.99336,-0.10653,0.54714,0.37581,0.47277,0.27377,-0.23721,-0.94234,-0.68503,-0.94912]
b = [0.1,0.7, 0.7,2.41,3.0, 1.7,-0.2,-0.88,-0.10, -0.10, 0.60,0.44,0.48,0.27,-0.23,-0.94,-0.68,-0.94]
d, path = dtw.dtw(a, b)
print 'distance:', d

plot_dtw(a, b, 'Query sample', '4th best match', path, d, 0)

plt.tight_layout()
plt.savefig('bestmatch_2_4.png', dpi=200)

plt.show()
# Out:
# distance: 0.670684504219
